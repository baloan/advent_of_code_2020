# %%
with open("day3_input.txt") as fh:
    lines = [s.strip() for s in fh]

# %%
lines
# Out:
# ['.#.....#..#..#....##.........#.',
#  '...#...#.........#..#.#..#.....',
#  '#.#...#.#....#.....#..#..##..##',
#  '..#..#.#.#.....#..#..#..##.....',
#  '.#..........#....####..##.#..#.',
#  '....##.......#.#.....#.........',
#  '....#......#....####.#.##......',
#  '........##..........##......#..',
#  '.........#........##..#.#.....#',
#  '.#..##..........#..#...#..##.#.',
#  '........#........#.....#....#.#',
#  '..#.......#.###...#.......##...',
#  '.##..##.#...#........#.........',
#  '...#....#..#..#..##.......#..#.',
#  '.#.#.##.##..##..#.#.....#.....#',
#  '....#.........#........#....##.',
#  '........#........#....###.#..#.',
#  '........#....#......##.........',
#  '.###.##.#.............##.......',
#  '....#.........#...#.#.##..#....',
#  '#.............#.#.#.#..#..#..##',
#  '###...###.###..#........#......',
#  '##..#.....#....##..##..........',
#  '.......#...#....#...#...#.....#',
#  '...#......###...##.###...#...#.',
#  '#.......#...##..#.......#..#...',
# ...
